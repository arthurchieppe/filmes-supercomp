# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
file = 'aleatoria.csv'
df = pd.read_csv(file, index_col=0)

# %%
df.head(5)
# Out:
#    n_movies  n_cat      time  n_output
# 0       1.0    1.0  0.006891       1.0
# 1       1.0    2.0  0.007348       1.0
# 2       1.0    3.0  0.008383       1.0
# 3       1.0    4.0  0.006436       1.0
# 4       1.0    5.0  0.007214       1.0

# %%
df.describe()
# Out:
#            n_movies         n_cat          time      n_output
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean   49951.000000      5.500000      0.056108      8.425100
# std    28868.942509      2.872425      0.028010      3.812433
# min        1.000000      1.000000      0.006436      0.000000
# 25%    24976.000000      3.000000      0.031954      6.000000
# 50%    49951.000000      5.500000      0.056335     10.000000
# 75%    74926.000000      8.000000      0.080410     11.000000
# max    99901.000000     10.000000      0.108612     16.000000

# %%
# Plot mean n_output for each n_movies
df_mean = df.groupby('n_movies').mean()
df_mean = df_mean.reset_index()
df_mean = df_mean[['n_movies', 'n_output']]
plt.plot(df_mean["n_movies"], df_mean["n_output"])

# %%
# Plot time vs n_movies
sns.lineplot(x='n_movies', y='time', data=df)
# Out:
# <Axes: xlabel='n_movies', ylabel='time'>

# %%
# Plot n_movie vs time and n_cat vs time in separate plots
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
sns.lineplot(data=df, x='n_movies', y='time', ax=ax[0])
sns.lineplot(data=df, x='n_cat', y='time', ax=ax[1])
# Out:
# <Axes: xlabel='n_cat', ylabel='time'>

# %%
# Plot 3d graph of the results
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['n_movies'], df['n_cat'], df['time'])
ax.set_xlabel('n_movies')
ax.set_ylabel('n_cat')
ax.set_zlabel('time')
plt.show()

# %%
# Plot interactive 3d graph of the results
import plotly.express as px
fig = px.scatter_3d(df, x='n_movies', y='n_cat', z='time')
fig.show()

# %%
# Group by n_movies and n_cats keeping the max value of n_movie for n_cat
temp = df.groupby(['n_cat']).mean().reset_index()
plt.plot(temp['n_cat'], temp['time'])

# %%
# Get rows where n_movies = 1001 or 2001 or 3001 or 4001 or 5001 or 6001 or 7001 or 8001 or 9001 or 10001
temp = df[df['n_movies'].isin([1001, 2001, 3001, 4001, 5001, 6001, 7001, 8001, 9001, 10001])]
# temp = df[df['n_movies'].isin([ 9001])]


# Plot n_cat vs time for each n_movies in the same plot
sns.lineplot(data=temp, x='n_cat', y='time', hue='n_movies')
plt.show()
